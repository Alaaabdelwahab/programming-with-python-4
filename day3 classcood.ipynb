# %%
tuple=("it","ele","math")
print(type(tuple))
print(tuple)
# Out:
# <class 'tuple'>
# ('it', 'ele', 'math')

# %%
set={"arabic","english","arabic"}
print(type(set))
print(set)
# Out:
# <class 'set'>
# {'arabic', 'english'}

# %%
dict={"name":"alaa" ,"school": "weschool" , "grade":"2"}
print(dict)
# Out:
# {'name': 'alaa', 'school': 'weschool', 'grade': '2'}

# %%
print(dict.items() )
# Out:
# dict_items([('name', 'alaa'), ('school', 'weschool'), ('grade', '2')])

# %%
print(dict.values() )
# Out:
# dict_values(['alaa', 'weschool', '2'])

# %%
print(dict.keys() )
# Out:
# dict_keys(['name', 'school', 'grade'])

# %%
x=10
y=35
if( x > y ):
    print("x is greter than y")
elif ( x == y ):
    print("x is equal y")
else:
    print("x is greter than y")
# Out:
# x is greter than y

# %%
a=float(input("enter number") )
if (a<0):
    print ("positive")
elif (a==0):
    print ("zero")
else :
    print("negative")
# Out:
# enter number 0
# zero

# %%
i=1
while( i<6 ):
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5
